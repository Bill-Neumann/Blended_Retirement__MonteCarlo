# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('SP500_CFund.csv')
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     1950-01-02    16.660000    17.090000    16.660000    17.090000
# 1     1950-01-09    17.080000    17.090000    16.650000    16.650000
# 2     1950-01-16    16.719999    16.940001    16.719999    16.940001
# 3     1950-01-23    16.920000    16.920000    16.730000    16.900000
# 4     1950-01-30    17.020000    17.350000    17.020000    17.350000
# 5     1950-02-06    17.320000    17.320000    17.209999    17.209999
# 6     1950-02-13    17.059999    17.230000    16.990000    17.230000
# 7     1950-02-20    17.200001    17.280001    17.170000    17.260000
# 8     1950-02-27    17.280001    17.330000    17.219999    17.330000
# 9     1950-03-06    17.320000    17.320000    17.070000    17.139999
# 10    1950-03-13    17.120001    17.490000    17.120001    17.490000
# 11    1950-03-20    17.440001    17.610001    17.440001    17.610001
# 12    1950-03-27    17.459999    17.530001    17.290001    17.340000
# ...

# %%
test = df.groupby(['Date'])
dups = test.size().reset_index()
dups[dups[0] > 1]
# Out:
# Empty DataFrame
# Columns: [Date, 0]
# Index: []

# %%
sp500 = df[['Date','Close','Volume']].copy()
sp500['Week_Close_Change'] = (sp500['Close'] - sp500['Close'].shift(1)) / sp500['Close'].shift(1)
for i in range(1,13):
    new_close = "Wk_Bak%d_Close" % i
    new_volume = "Wk_Bak%d_Volume" % i
    close_change = "Wk_Bak%d_Close_Change" % i
    sp500[new_close] = sp500['Close'].shift(i)
    sp500[new_volume] = sp500['Volume'].shift(i)
    sp500[close_change] = (sp500['Close'].shift(i) - sp500['Close'].shift(i+1)) / sp500['Close'].shift(i+1)
sp500.replace([np.inf, -np.inf], np.nan,inplace=True)
sp500.dropna(inplace=True)
sp500
# Out:
#             Date        Close       Volume  Week_Close_Change  Wk_Bak1_Close  \
# 13    1950-04-03    17.820000      8100000           0.027682      17.340000
# 14    1950-04-10    17.860001     12680000           0.002245      17.820000
# 15    1950-04-17    17.950001     15350000           0.005039      17.860001
# 16    1950-04-24    18.070000     11440000           0.006685      17.950001
# 17    1950-05-01    18.330000     11620000           0.014388      18.070000
# 18    1950-05-08    18.200001      9390000          -0.007092      18.330000
# 19    1950-05-15    18.709999     13220000           0.028022      18.200001
# 20    1950-05-22    18.650000      8210000          -0.003207      18.709999
# 21    1950-05-29    18.790001      5670000           0.007507      18.650000
# 22    1950-06-05    19.260000      9540000           0.025013      18.790001
# 23    1950-06-12    18.969999      7940000          -0.015057      19.260000
# ...

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# define X and y
feature_cols = []
for i in range(1,13):
    close_change = "Wk_Bak%d_Close_Change" % i
    feature_cols.append(close_change)
feature_cols
# Out:
# ['Wk_Bak1_Close_Change',
#  'Wk_Bak2_Close_Change',
#  'Wk_Bak3_Close_Change',
#  'Wk_Bak4_Close_Change',
#  'Wk_Bak5_Close_Change',
#  'Wk_Bak6_Close_Change',
#  'Wk_Bak7_Close_Change',
#  'Wk_Bak8_Close_Change',
#  'Wk_Bak9_Close_Change',
#  'Wk_Bak10_Close_Change',
#  'Wk_Bak11_Close_Change',
#  'Wk_Bak12_Close_Change']

# %%
# fix random seed for reproducibility
seed = 7
np.random.seed(seed)
# define X and y
X = sp500[feature_cols].as_matrix()
y = sp500["Week_Close_Change"].as_matrix()

# define 6-fold cross validation test harness
kfold = StratifiedKFold(n_splits=6, shuffle=True, random_state=seed)
cvscores = []

# Create linear regression object
regr = linear_model.LinearRegression()

# %%
for (train, test) in kfold.split(X, y):
    # train logistic regression model
    regr.fit(X[train], y[train])
    
    # make predictions for testing set
    y_pred_class = regr.predict(X[test])
    
    # calculate testing accuracy
    score = metrics.accuracy_score(y[test], y_pred_class) * 100
    cvscores.append(score)
    print("acc: ",score,"%")
    cm = []
    cm = metrics.confusion_matrix(y[test], y_pred_class)
    conf_mat = conf_mat + cm
        
    # Compute ROC curve and area the curve
    probas_ = logreg.predict_proba(X[test])
    fpr, tpr, thresholds = roc_curve(y[test], probas_[:, 1])
    mean_tpr += interp(mean_fpr, fpr, tpr)
    mean_tpr[0] = 0.0
    roc_auc = auc(fpr, tpr)
#    plt.plot(fpr, tpr, lw=lw, color=color,
#             label='ROC fold %d (area = %0.2f)' % (i, roc_auc))
    i += 1
# Out:
# array([[-0.01533225,  0.00686112,  0.02042013, ..., -0.00236133,
#          0.01741748, -0.02574605],
#        [ 0.02768166, -0.01533225,  0.00686112, ...,  0.02662722,
#         -0.00236133,  0.01741748],
#        [ 0.00224473,  0.02768166, -0.01533225, ..., -0.00806922,
#          0.02662722, -0.00236133],
#        ...,
#        [ 0.00308153, -0.00540745,  0.02414191, ..., -0.05950196,
#         -0.01240236,  0.03541851],
#        [ 0.00488366,  0.00308153, -0.00540745, ...,  0.02032644,
#         -0.05950196, -0.01240236],
#        [ 0.01623988,  0.00488366,  0.00308153, ..., -0.01378339,
#          0.02032644, -0.05950196]])
